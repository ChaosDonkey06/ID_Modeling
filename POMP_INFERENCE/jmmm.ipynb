# %%
import matplotlib.pyplot as plt
import numpy as np
import random


# Probability to move up or down
prob = [0.05, 0.95]

# statically defining the starting position
start     = 2
positions = [start]


# creating the random points
rr    = np.random.random(1000)
downp = rr < prob[0]
upp   = rr > prob[1]

for idownp, iupp in zip(downp, upp):
    down = idownp and positions[-1] > 1
    up   = iupp and positions[-1] < 4
    positions.append(positions[-1] - down + up)

# %%
fig, ax = plt.subplots(1,1,figsize=(15.2, 7.2))


ax.plot(positions)

# %%
from scipy.stats import norm

media    = 0
varianca = 0.1

def get_truncated_normal(mean=0, sd=1, low=0, upp=10):
    return norm( loc=mean, scale=sd )

norm       = get_truncated_normal(media, varianca**(1/2))


variancazz = [var_1, var_2] # magnitud del random walk

all = [10]
for n in range(1, 100):
    x_post, p_post = eafk(...)
    p_post = p_prior + dx,  # dx = [num_param, num_ens]

    dx_random_walks = np.sign(dx)*norm.rvs(size=(num_param, num_enembles))
    p_post          = 
    all.append(all[n-1] + norm.rvs(1))

# %%
fig, ax = plt.subplots(1, 1, figsize=(15.2, 7.2))
ax.plot(np.array(all), marker="o")
# Out:
# /var/folders/7p/jp6xqkvn5wb6ddl1fn0bhs980000gn/T/ipykernel_78298/2887575024.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ax.plot(np.array(all), marker="o")

# %%
r0 = 2
(1-1/r0), (1-1/(r0+0.05))

r0 = beta * 7
0.05/7 = beta- betax
# Out:
# (0.5, 0.5121951219512195)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15.2, 7.2))
ax.plot(np.diff(all), marker="o")
# Out:
# /Users/chaosdonkey06/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)
